# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
def read_photo(path):
    img = cv.imread(path)
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    return img

# %%
path = 't1.jpeg'
img = read_photo(path)
plt.imshow(img)
plt.show()

# %%
def edge_mask(img, line_size, blur_value):
    gray = cv.cvtColor(img, cv.COLOR_RGB2GRAY)
    gray_blur = cv.medianBlur(gray, blur_value)

    edges = cv.adaptiveThreshold(gray_blur,255, cv.ADAPTIVE_THRESH_MEAN_C,cv.THRESH_BINARY,line_size,blur_value)

    return edges

# %%
line_size = 17
blur_value = 3
e_img = edge_mask(img, line_size, blur_value)
plt.imshow(e_img, cmap = 'gray')
plt.show()

# %%
def save_img(img):
    img_no = np.random.randint(0,100)
    img_name = "image{}.jpeg".format(img_no)
    cv.imwrite(img_name,img)

# %%
save_img(e_img)
